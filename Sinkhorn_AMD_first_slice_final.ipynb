# %% [markdown]
# In this notebook we give an implementation of De-March and Labordere's approach to constructing arbitrage
# free implied volatility surfaces, outlined in https://arxiv.org/abs/1902.04456.
#
# In particular we focus on the construction of the first slice.
#
# In this notebook we will use AMD options data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math 

from scipy.stats import norm
from scipy.optimize import fsolve
from scipy.optimize import minimize
import scipy.integrate as integrate
from scipy import special
from scipy.special import erf, erfc
from scipy import optimize
from datetime import date
from datetime import datetime
import time

# %%
# Preprocessing
path = 'https://raw.githubusercontent.com/coolejungenhihi/volsurface_Sinkhorn/main/amd_quotedata.csv'
amd_quotes = pd.read_csv(path, parse_dates=['Expiration Date'], index_col=['Expiration Date'])
amd_calls = amd_quotes.iloc[:,0:11] # Remove puts

S0 = 92.3
t0 = date(2023, 4, 8)
amd_calls['Strike/Spot'] = amd_calls['Strike']/S0
amd_calls['Mid'] = (amd_calls['Bid']+amd_calls['Ask'])/2
amd_calls
# Out:
#                               Calls  Last Sale    Net    Bid    Ask  Volume  \
# Expiration Date
# 2023-04-06       AMD230406C00083000       9.50  0.000   9.35   9.55     126
# 2023-04-06       AMD230406C00084000       8.70  0.275   8.35   8.55      35
# 2023-04-06       AMD230406C00085000       7.55  0.150   7.35   7.55     180
# 2023-04-06       AMD230406C00086000       6.63  0.205   6.35   6.55      60
# 2023-04-06       AMD230406C00087000       5.61  0.110   5.35   5.60     320
# ...                             ...        ...    ...    ...    ...     ...
# 2025-12-19       AMD251219C00120000      21.43 -0.220  20.95  22.30      23
# 2025-12-19       AMD251219C00125000      19.20 -1.000  19.85  20.80       5
# 2025-12-19       AMD251219C00130000      17.55 -1.225  18.50  19.45      10
# 2025-12-19       AMD251219C00135000      17.30  0.000  17.25  18.20       0
# 2025-12-19       AMD251219C00140000      16.50  0.175  16.10  16.95       5
#
# ...

# %%
# Separate our calls with a single expiry
C1 = amd_calls.loc['2023-04-14']
C1 = C1.reset_index(drop=True)
C1
# Out:
#                  Calls  Last Sale    Net   Bid   Ask  Volume      IV   Delta  \
# 0   AMD230414C00083000       9.72 -0.105  9.55  9.80     166  0.4442  0.9452
# 1   AMD230414C00084000       9.05  0.150  8.65  8.85      22  0.4504  0.9287
# 2   AMD230414C00085000       8.10  0.075  7.70  7.90     134  0.4427  0.9068
# 3   AMD230414C00086000       7.00 -0.125  6.80  7.00      77  0.4352  0.8782
# 4   AMD230414C00087000       6.20 -0.125  5.95  6.15     101  0.4259  0.8417
# 5   AMD230414C00088000       5.50 -0.050  5.15  5.30     192  0.4269  0.7974
# 6   AMD230414C00089000       4.50 -0.300  4.40  4.50     165  0.4155  0.7456
# 7   AMD230414C00090000       3.76 -0.340  3.70  3.80     817  0.4147  0.6869
# 8   AMD230414C00091000       3.07 -0.380  3.05  3.15    1194  0.4062  0.6223
# 9   AMD230414C00092000       2.50 -0.365  2.48  2.50    8647  0.4024  0.5529
# 10  AMD230414C00093000       1.98 -0.375  1.95  1.99    8374  0.3973  0.4806
# ...

# %%
# Utility function to calculate implied volatily for plotting later
def iv(p,K,T,r,S0):
    """
    Calculate implied volatility using Black-Scholes formula
    
    Parameters:
    p (float): Market price(s) of the option
    K (float): Strike price(s) of the option
    T (float): Time to expiry of the option, in years
    r (float): Risk-free interest rate, as a decimal
    S0 (float): Current price of the underlying asset
    """
    
    d1 = lambda sigma: (np.log(S0/K) + (r + 0.5*(sigma**2))*T) / (sigma*np.sqrt(T))
    d2 = lambda sigma: d1(sigma) - sigma*np.sqrt(T)
    option_price = lambda sigma: S0*norm.cdf(d1(sigma)) - K*np.exp(-r*T)*norm.cdf(d2(sigma))
    option_price_diff = lambda sigma: option_price(sigma) - p
    
    return fsolve(option_price_diff, 0.2*np.ones(len(p)))

# %%
# Split up the data for use in the algorithm, plot to get first look
r = 0.01 # Todo: figure out r
ask = np.array(C1['Ask'])
bid = np.array(C1['Bid'])
mid = np.array(C1['Mid'])
K = np.array(C1['Strike'])
numK = len(K)
t1 = 6/252

# Plot data
fig, ax = plt.subplots()
ax.plot(np.array(C1['Strike/Spot']), np.array(iv(bid,K,t1,r,S0)), 'b.', label='Bid')
ax.plot(np.array(C1['Strike/Spot']), np.array(iv(ask,K,t1,r,S0)), 'g.', label='Ask')
ax.plot(np.array(C1['Strike/Spot']), np.array(iv(mid,K,t1,r,S0)), 'r--', label='Mid')
plt.legend()
plt.show()

# %% [markdown]
# Let us now implement the algorithm

# %%
#Pre-compute constants
global SQRT_PI, SQRT2, INV_SQRT2_PI, INV_SQRT2, I_CONST
SQRT2 = np.sqrt(2)
INV_SQRT2 = 1. / SQRT2
SQRT2_PI = np.sqrt(2. * np.pi)
INV_SQRT2_PI = 1. / SQRT2_PI
I_CONST = INV_SQRT2_PI / 2.

# %% [markdown]
# Calculation of $\sigma_0$ definition of $m_0, I_u,I_h, I_Q, G_{0,1}$

# %%
# Objective function for the minimization for sigma_0
def sigma_objective(sigma,S0,delta_t):
    sigma += 1e-100 # To stop divide by zero errors
    sqrtt = math.sqrt(delta_t)
    help_v = (K-S0)/(SQRT2*sqrtt*sigma)
    B_vec = 0.5*(S0-K)*erf(help_v) + sigma*sqrtt*INV_SQRT2_PI*np.exp(-help_v**2)
    return np.sum((B_vec-mid)**2)


def calculate_sigma0(S0,delta_t):
    res = optimize.minimize_scalar(sigma_objective,args = (S0,delta_t))
    return res.x

#visulaise if result makes sense
sigma0 = calculate_sigma0(S0,t1)
xx = np.linspace(0,100,500)
f = lambda x: sigma_objective(x,S0,t1)
f_ = np.vectorize(f)
plt.plot(xx,f_(xx))
print(sigma0)
P1 = lambda s1: 1
# P1 = lambda s1: 1 if s1 == S0 else 0

def m0(s2,s1,delta_t,P1):
    '''
    m0: Joint distribution of (s1,s2)
    P1: Marginal distribution of s1
    (Here we use the general notation of the paper, this is the special case of m_0 for time one tho,
    so s2 will be S_1 and s1 S_0 )
    '''
    #renormalise m_0 on R^+
    sigma0 = calculate_sigma0(s1,delta_t)
    return norm.pdf(s2,s1,sigma0*np.sqrt(delta_t)) / norm.cdf(s1/(sigma0*np.sqrt(delta_t))) * (s1 >= 0)

#define f
def f1(V,omega):
    delta_C_bid = bid - mid
    delta_C_ask = ask - mid
    l = np.zeros(numK)
    
    for i in range(numK):
        if (V[i]*omega[i] <= delta_C_ask[i]) and (V[i]*omega[i] >= delta_C_bid[i]):
            l[i] = V[i]*V[i]*omega[i]/2
        elif V[i]*omega[i] > delta_C_ask[i]:
            l[i] = delta_C_ask[i]*V[i] - delta_C_ask[i]**2/(2*omega[i])
        else: 
            l[i] = delta_C_bid[i]*V[i] - delta_C_bid[i]**2/(2*omega[i])
            
    return l


def grad_f1(V,omega):
    """
    Gradient of g1 with respect to V_K
    """
    delta_C_bid = bid - mid
    delta_C_ask = ask - mid
    g = np.zeros(numK)
    
    for j in range(numK):
        if (V[j]*omega[j] <= delta_C_ask[j]) and (V[j]*omega[j] >= delta_C_bid[j]):
            g[j] = V[j]*omega[j]
        elif V[j]*omega[j] > delta_C_ask[j]:
            g[j] = delta_C_ask[j]
        else: 
            g[j] = delta_C_bid[j]
    
    return g
# Out:
# 82.26725329153062

# %%
#Closed / semi closed form expressions for some useful integrals from remark 4.3 in the paper
def I1(alpha,sigma,s1,K1,K2): 
    A, B = (K1-s1)/sigma, (K2-s1)/sigma
    return 1/2*np.exp((alpha*sigma)**2/2 + alpha*s1) * (erf((B-alpha*sigma)*INV_SQRT2) - erf((A-alpha*sigma)*INV_SQRT2) )
    
def I2(alpha,sigma,s1,K1,K2):
    A, B = (K1-s1)/sigma, (K2-s1)/sigma
    return sigma*np.exp(alpha*s1) * ( 2*(np.exp(A*alpha*sigma-A*A/2) - np.exp(B*alpha*sigma-B*B/2)) + SQRT2_PI*alpha*sigma*np.exp(alpha*sigma*alpha*sigma/2)*(erf((B-alpha*sigma)*INV_SQRT2) - erf((A-alpha*sigma)*INV_SQRT2)) )
    
def I3(alpha,sigma,s1,K1,K2,Q):
    A, B = (K1-s1)/sigma, (K2-s1)/sigma
    return np.exp(alpha*s1) *  (2*sigma*(np.exp(A*alpha*sigma-A**2/2) - np.exp(B*alpha*sigma-B**2/2)) + SQRT2_PI*np.exp(alpha*alpha*sigma*sigma/2)*(alpha*sigma**2-Q+s1) * (erf((B-alpha*sigma)*INV_SQRT2) - erf((A-alpha*sigma)*INV_SQRT2)) )

def I4(alpha,sigma,s1,K1,K2,K,Q):
    A, B = (K1-s1)/sigma, (K2-s1)/sigma  
    return 2*sigma* (np.exp(alpha*A*sigma-A*A/2)*(sigma*(alpha*sigma+A) - K - Q + 2*s1) + np.exp(-1/2*B*(B-2*alpha*sigma))*(-sigma*(alpha*sigma+B) + K + Q -2*s1)) + SQRT2_PI*np.exp(alpha*sigma*alpha*sigma/2)*(erf((B-alpha*sigma)/(np.sqrt(2))) - erf((A-alpha*sigma)*INV_SQRT2) ) * (sigma**2 - (-alpha*sigma**2+K-s1)*(alpha*sigma**2-Q+s1))

# %%
#Calculate I_u via numerical integration to later check the closed form
def I_u_integrand(s,theta,V,K,s1,delta_t,P1):
    return np.exp(-np.sum(V*np.maximum(s-K,0))-theta*(s-s1))*m0(s,s1,delta_t,P1)

def I_u(theta,V,K,s1,K1,K2,delta_t,P1):
    return integrate.quad(I_u_integrand,K1,K2,args=(theta,V,K,s1,delta_t,P1) )[0]

#I_u closed form for use in the optimisation
def I_u_(theta,V,K,s1,K1,K2,delta_t,P1):
    sigma0 = calculate_sigma0(s1,delta_t)
    sigma = sigma0*np.sqrt(delta_t)
    totI = 0

    for i in range(-1,numK): 
        alpha = -sum(V[:i+1]) - theta
        gamma = sum(V[:i+1]*K[:i+1]) + (theta*s1)
        #print(f'alpha = {alpha}')
        #print(f'sigma = {sigma}')

        if i == -1: 
            newPiece = np.exp(gamma) * I1(alpha,sigma,s1,K1,K[0])
        elif i >= 0 and i < numK-1:
            newPiece = np.exp(gamma) * I1(alpha,sigma,s1,K[i],K[i+1]) # Piecewise integration
        else:
            newPiece = np.exp(gamma) * I1(alpha,sigma,s1,K[-1],K2)
        
        #print(f' i = {i}: newPiece = {newPiece}')
        totI += newPiece
    
    return totI

#set debug to true to check if numerical and closed form integration yield the same results
debug = False
if debug:
    # Check whether symbolic integration is correct
    print(I_u(0,np.zeros(numK),K,S0,0,K[0],t1,P1))
    for i in range(0,numK-1):
        print(I_u(0,np.zeros(numK),K,S0,K[i],K[i+1],t1,P1))
    print(I_u(0,np.zeros(numK),K,S0,K[-1],110,t1,P1))

    print("----")

    print(I_u_(0,np.zeros(numK),K,S0,0,110,t1,P1))
    print(I_u(0,np.zeros(numK),K,S0,0,110,t1,P1))

    print("---------")
    print(I_u_(np.zeros(4),np.zeros(numK),K,S0,0,110,t1,P1)) # theta can also be a list

# %%
#Calculate I_h via numerical integration to later check the closed form
def I_h_0_integrand(s,theta,V,K,s1,delta_t,P1):
    return np.exp(-np.sum(V*np.maximum(s-K,0))-theta*(s-s1))*m0(s,s1,delta_t,P1)*(s-s1)

def I_h_0(theta,V,K,s1,K1,K2,delta_t,P1):
    return integrate.quad(I_h_0_integrand,K1,K2,args=(theta,V,K,s1,delta_t,P1))[0]

#I_h closed form for later use in the optimisation
def I_h_0_(theta,V,K,s1,K1,K2,sigma0,delta_t,P1):
    sigma0 = calculate_sigma0(s1,delta_t)
    sigma = sigma0*np.sqrt(delta_t)
    totI = 0
    
    for i in range(-1,numK): 
        alpha = -sum(V[:i+1]) - theta
        gamma = sum(V[:i+1]*K[:i+1]) + (theta*S0)
        
        if i == -1: 
            newPiece = np.exp(gamma) * I_CONST * I2(alpha,sigma,s1,K1,K[0])
        elif i >= 0 and i < numK-1:
            newPiece = np.exp(gamma) * I_CONST * I2(alpha,sigma,s1,K[i],K[i+1])
        else:
            newPiece = np.exp(gamma) * I_CONST * I2(alpha,sigma,s1,K[-1],K2)
        
        #print(f' i = {i}: newPiece = {newPiece}')
        totI += newPiece
    
    return totI

#set debug to true to check if numerical and closed form integration yield the same results
debug = False
if debug:
    # Check whether symbolic integration is correct
    print(I_h_0(0,np.zeros(numK),K,S0,0,K[0],t1,P1))
    for i in range(0,numK-1):
        print(I_h_0(0,np.zeros(numK),K,S0,K[i],K[i+1],t1,P1))
    print(I_h_0(0,np.zeros(numK),K,S0,K[-1],110,t1,P1))

    print("----")

    print(I_h_0_(0,np.zeros(numK),K,S0,0,110,sigma0,t1,P1))
    print(I_h_0(0,np.zeros(numK),K,S0,0,110,t1,P1))

    print("---------")
    print(I_h_0_(np.zeros(4),np.zeros(numK),K,S0,0,110,sigma0,t1,P1)) # theta can also be a list

def I_h_0_grad_integrand(s,theta,V,K,s1,delta_t,P1):
    return -np.exp(-np.sum(V*np.maximum(s-K,0))-theta*(s-S0))*m0(s,s1,delta_t,P1)*(s-s1)**2
    
def I_h_0_grad(theta,V,K,s1,K1,K2,sigma0,delta_t,P1):
    return integrate.quad(I_h_0_grad_integrand,K1,K2,args=(theta,V,K,s1,delta_t,P1))[0]


def I_h_0_hessian_integrand(s,theta,V,K,s1,sigma0,delta_t,P1):
    return np.exp(-np.sum(V*np.maximum(s-K,0))-theta*(s-s1))*m0(s,s1,delta_t,P1)*(s-s1)**3

def I_h_0_hessian(theta,V,K,s1,K1,K2,sigma0,delta_t,P1):
    return integrate.quad(I_h_0_hessian_integrand,K1,K2,args=(theta,V,K,s1,sigma0,delta_t,P1))[0]

# %%
# Find proper bounds for h root finding 

u1, h1, V = 0., 0., np.array([0.]*numK)
V_prev = np.array([1] *numK)
Lambda = 0.1
omega_K = Lambda * np.abs(ask - bid)
delta_t = t1
P1 = lambda s1: 1

xx = np.linspace(-0.01,0.01,100)
yy = []
for x in xx:
    yy.append(I_h_0_(x,V,K,S0,S0-50,S0+50,sigma0,t1,P1))
    
plt.figure(figsize=(12,4))
plt.plot(xx,yy)

# %%
#I_Q numerical integration for comparison
def I_Q_integrand(s,h0,V,K,Q,s1,delta_t,P1):
    return math.exp(-np.sum(V*np.maximum(s-K,0))-h0*(s-S0))*m0(s,s1,delta_t,P1)*np.maximum(s-Q,0)

def I_Q(h0,V,K,Q,s1,K1,K2,delta_t,P1):
    return integrate.quad(I_Q_integrand,K1,K2,args=(h0,V,K,Q,s1,delta_t,P1))[0]

#I_Q closed form 
I_Q_CONST = 1/(2*np.sqrt(2*math.pi))
def I_Q_(h0,V,K,Q,s1,K1,K2,delta_t,P1):
    sigma0 = calculate_sigma0(s1,delta_t)
    sigma = sigma0*np.sqrt(delta_t)
    Q = np.array(Q)
    if (Q.shape == ()):
      totI = np.zeros(1)
    else:
      totI = np.zeros(Q.shape)

    for i in range(-1,numK): 
        alpha = -sum(V[:i+1]) - h0 
        gamma = sum(V[:i+1]*K[:i+1]) + h0*S0
        
        if i == -1: 
            newPiece = np.exp(gamma) * I_Q_CONST * I3(alpha,sigma,s1,Q,K[0],Q) * (K[0] >= Q)
        elif i >= 0 and i < numK-1:
            newPiece = np.exp(gamma) * I_Q_CONST * I3(alpha,sigma,s1,np.maximum(Q,K[i]),K[i+1],Q) * (K[i+1] >= Q)
        else:
            newPiece = np.exp(gamma) * I_Q_CONST * I3(alpha,sigma,s1,np.maximum(Q,K[-1]),K2,Q)
            
        #print(f' i = {i}: newPiece = {newPiece}')
        totI += newPiece

    return totI

#set debug to True to check if closed form correct
debug = False
if debug:
    # Check whether symbolic integration is correct
    print(I_Q(0,np.zeros(numK),K,K[0],S0,0,K[0],t1,P1))
    for i in range(0,numK-1):
        print(I_Q(0,np.zeros(numK),K,K[0],S0,K[i],K[i+1],t1,P1))
    print(I_Q(0,np.zeros(numK),K,K[0],S0,K[-1],110,t1,P1))

    print("----")
    # Check for different Q's
    print(I_Q_(0,np.zeros(numK),K,K[0]-10,S0,0,110,t1,P1))
    print(I_Q(0,np.zeros(numK),K,K[0]-10,S0,0,110,t1,P1))

    print(I_Q_(0,np.zeros(numK),K,K[0],S0,0,110,t1,P1))
    print(I_Q(0,np.zeros(numK),K,K[0],S0,0,110,t1,P1))

    print(I_Q_(0,np.zeros(numK),K,K[3],S0,0,110,t1,P1))
    print(I_Q(0,np.zeros(numK),K,K[3],S0,0,110,t1,P1))

    print(I_Q_(0,np.zeros(numK),K,K[-1],S0,0,110,t1,P1))
    print(I_Q(0,np.zeros(numK),K,K[-1],S0,0,110,t1,P1))

    print(I_Q_(0,np.zeros(numK),K,K[-1]+5,S0,0,110,t1,P1))
    print(I_Q(0,np.zeros(numK),K,K[-1]+5,S0,0,110,t1,P1))

# %%
def G1(V,u0,h0,K,omega,S0,delta_t,P1):
    expectation = I_u_(h0,V,K,S0,S0-50, S0+50,delta_t,P1)*np.exp(-u0)
    return u0 + np.sum(V*mid) + np.sum(f1(V,omega)) + expectation

    
def grad_G1(V,u0,h0,K,omega,S0,delta_t,P1):
    """
    Gradient of G_12 with respect to V_K_i
    """
    gf1 = grad_f1(V,omega)
    grad = np.zeros(numK)
    grad = gf1 + mid - I_Q_(h0,V,K,K,S0,S0-50,S0+50,delta_t,P1)*np.exp(-u0) # second K is Q in notation
    
    #print(f'Grad = {grad}')
    #print(f'Grad norm = {np.linalg.norm(grad)}')
    return grad

#Definition of the Hessian of G_1 , note that we couldn't make it work so this won't actually be used and we 
# will use a quasi Newton algorithm for minimizing over V as suggested as an alternative in the paper
def Hess_G1(V,u0,h0,K,omega,S0,delta_t,P1):
    '''
    Hessian of G_12
    '''
    #calculate the expectation appearing in the Hessian
    Max = np.zeros((numK,numK))
    Sum = np.zeros((numK,numK))
    Prod = np.zeros((numK,numK))
    for i in range(numK):
        for j in range(numK):
            Max[i,j] = max(K[i], K[j])
            Sum[i,j] = K[i] + K[j]
            Prod[i,j] = K[i] * K[j]

    # Pre-compute some constants
    std = sigma0 * np.sqrt(delta_t)
    H_help = (Max - S0)/(np.sqrt(2)*std)
    RENORM_CONST =  1/norm.cdf(S0/(sigma0*np.sqrt(delta_t)))
    H = (std**2 + S0**2 - Sum*S0 + Prod)/2. * erfc(H_help) \
        + std * np.exp(-H_help**2) * INV_SQRT2_PI * (Max + S0 - Sum)
    H *= RENORM_CONST

    #calculate del_V_j^2 f  
    delta_C_bid = bid - mid
    delta_C_ask = ask - mid
    
    help_v_1 = np.less_equal(V*omega,delta_C_ask ).astype(int)
    help_v_2 = np.greater_equal(V*omega,delta_C_bid).astype(int)
    diag_f_del_2 = V*(help_v_1 + help_v_2 - 1)
    f_del_2 = np.diag(diag_f_del_2)
    #H = f_del_2 + H

    # Our attempt at calculating the actual Hessian
    #e0 = np.exp( -S0**2 / (2*std**2) - u0 - S0*sum(V) + np.dot(K,V) + ((h0 + sum(V))**2*std**2)/2)
    #exponential = np.exp( -(Max**2 + S0**2) / (2*std**2) - u0 - (Max+S0)*sum(V) + np.dot(K,V) )
    #e1 = SQRT2_PI * (std**2*(h0 + sum(V))*((h0 + sum(V))*std**2 - 2*S0 + Sum) + 1 ) + S0**2 - S0*Sum + Prod
    #e2 = np.exp(((Max+(h0+sum(V))*std**2)**2 + S0**2)/(2*std**2)) * erf((Max+(h0+sum(V))*std**2-S0)/(SQRT2*std))
    #e3 = 2 * std * (Max - (h0 + sum(V))*std**2 + S0 - Sum)
    #e4 = np.exp((S0*(Max+(h0+sum(V))*std**2))/std**2)
    #H = exponential * (e1*e2 - e3*e4) / (2*np.sqrt(2*np.pi))
    #H = f_del_2 - (e0*e1 - H) * RENORM_CONST
    
    return H

# %% [markdown]
# Run the algorithm outlined in the Paper:
#
# For the optimisation over V we choose the quasi Newton algorithm TNC as we couldn't get the Hessian to work, and in the paper they mentioned this as a possible alternative. Note how ever that this will be slower than if a Hessian would be provided.
#
# As a convergance critera we choose $||x_n - x_{n+1}|| < \varepsilon$, where $x_n$ denotes the vector of our variables $(u,h,V)$ after the n-th steph of the iteration,as this has proven to be the most stable for us
# and is not subject to potential errors in the implementation of the full gradient of G.
#
# However from the convergance result in the paper $||\nabla G ||< \varepsilon $ would be a possible choice as well, that also gurantees that the algorithm only stops when an actual minimum is found and the optimisers didnt just get stuck.

# %% [markdown]
# Important remark!
#
# The results of the following algorithm for the AMD data set produced a vol smile that didn't fit into bid ask for some people in our group and worked for others. We are not entirely sure why this was the case. Our only idea why this happens is that it's due to different python / package versions.
#
# One of the configurations it worked under is the following: Python 3.9.12, scipy 1.7.3 , numpy 1.21.5
#
# In case this doesn't work we report the numbers obtained when the optimisation worked below for generating the plots

# %%
#Initial guesses for the parameters + definition of a few constans
u1, h1, V = 0., 0., np.array([0.]*numK)
V_prev = np.array([1] *numK)
Lambda = 0.1
omega_K = Lambda * np.abs(ask - bid)
delta_t = t1
P1 = lambda s1: 1
sigma0 = calculate_sigma0(S0,delta_t)

#set debug to True to see output of minimisations
debug = False
start = time.time()
while np.linalg.norm(V-V_prev)/np.linalg.norm(V_prev) > 1e-5:
    V_prev = V
    #projection on h and u
    h0 = optimize.root_scalar(I_h_0_,args=(V,K,S0,S0-50, S0+50,sigma0,delta_t,P1) ,bracket = [-0.1,0.1],x0=0.00005, fprime = I_h_0_grad, fprime2 = I_h_0_hessian).root
    u0 = np.log(I_u_(h0,V,K,S0,S0-50, S0+50,delta_t,P1))

    #optimisation of G over V using quasi Newton
    V = optimize.minimize(fun= G1, x0=V, args=(u0,h0,K,omega_K,S0,delta_t,P1), method='TNC', jac= grad_G1, hess=None, hessp=None, bounds=None, constraints=(), tol=1e-5, callback=None, options=None).x

    # Optimisation using Newton-CG which requires a Hessian
    #V = optimize.minimize(fun= G1, x0=V, args=(u0,h0,K,omega_K,S0,delta_t,P1), method='Newton-CG', jac= grad_G1, hess=Hess_G1, hessp=None, bounds=None, constraints=(), tol=1e-5, callback=None, options=None).x
    
    if debug:
        print(f' h0 = {h0}')
        print(f' u0 = {u0}')
        print(f'V = {V}')
        print(f'normdiff = {np.linalg.norm(V-V_prev)/np.linalg.norm(V_prev)}')
        print("----------")
end = time.time()
print("elapsed time = ",end-start)
# Out:
# C:\Users\lachl\AppData\Local\Temp/ipykernel_24028/3352366036.py:13: RuntimeWarning: divide by zero encountered in double_scalars
#   while np.linalg.norm(V-V_prev)/np.linalg.norm(V_prev) > 1e-5:
# C:\Users\lachl\AppData\Local\Temp/ipykernel_24028/2310180688.py:12: RuntimeWarning: overflow encountered in exp
#   return np.exp(alpha*s1) *  (2*sigma*(np.exp(A*alpha*sigma-A**2/2) - np.exp(B*alpha*sigma-B**2/2)) + SQRT2_PI*np.exp(alpha*alpha*sigma*sigma/2)*(alpha*sigma**2-Q+s1) * (erf((B-alpha*sigma)*INV_SQRT2) - erf((A-alpha*sigma)*INV_SQRT2)) )
# C:\Users\lachl\AppData\Local\Temp/ipykernel_24028/2310180688.py:12: RuntimeWarning: invalid value encountered in multiply
#   return np.exp(alpha*s1) *  (2*sigma*(np.exp(A*alpha*sigma-A**2/2) - np.exp(B*alpha*sigma-B**2/2)) + SQRT2_PI*np.exp(alpha*alpha*sigma*sigma/2)*(alpha*sigma**2-Q+s1) * (erf((B-alpha*sigma)*INV_SQRT2) - erf((A-alpha*sigma)*INV_SQRT2)) )
# elapsed time =  0.808480978012085

# %% [markdown]
# Below commented out are the numbers one gets on a system where the algorithm converged correctly.
# If the vol smile plots below don't fit into bid ask uncomment these and price and plot again , this should then yield
# the correct plots.

# %%
#u0 = 0.19285325319381114
#h0 = -0.06873284809603622
#V = [-0.05838185 ,-0.39953477,  0.14261953,  0.26025927, -0.090369,    0.05843527, 0.28859106, \
#      -0.12859567, -0.33677541,  0.26208302,  0.15748821, -0.03362643,0.02289501, -0.02146696, \
#      0.15423403, -0.02724625,  0.03377713,  0.15464584, 0.08936,    -0.25662016]

# %% [markdown]
# With or obtained measure / pdf we may now price Calls with arbitrary strike from which we can back out sigma(K)

# %%
n = numK*200 # choose how many points to use by adjusting the constant number, makes sure data is on grid
xx = np.linspace(83, 102, n, endpoint = True)
c = I_Q_(h0,V,K,xx,S0,50,120,delta_t,P1)/I_u_(h0,V,K,S0,50,120,delta_t,P1) #reprice calls
#alternative to price the calls (yields the same result)
#c = I_Q_(h0,V,K,xx,S0,50,120,delta_t,P1)*np.exp(-u0)

# %%
# Plot vol smile
fig, ax = plt.subplots()
fig.set_size_inches(12,4)
T_ = t1
ax.plot(np.array(C1['Strike/Spot']), np.array(iv(bid,K,T_,r,S0)), 'b.', label='Bid')
ax.plot(np.array(C1['Strike/Spot']), np.array(iv(ask,K,T_,r,S0)), 'g.', label='Ask')
ax.plot(np.array(C1['Strike/Spot']), np.array(iv(mid,K,T_,r,S0)), 'r--', label='Mid')
v = np.zeros(n)
for i in range(n):
    v[i] = iv(np.array([c[i]]), np.array([xx[i]]), T_, r, S0)
ax.plot(xx / S0, v, 'k', label='Vol smile')
ax.set_ylabel('IV')
ax.set_xlabel('Moneyness')
plt.legend()
plt.show()

# %%
#Calculate implied pdf 
xx = np.linspace(70,120,200)
for x in xx:
    c = I_Q_(h0,V,K,xx,S0,S0-50,S0+50,delta_t,P1)*np.exp(-u0)
    c_p = I_Q_(h0,V,K,xx+0.1,S0,S0-50,S0+50,delta_t,P1)*np.exp(-u0)
    c_m =  I_Q_(h0,V,K,xx-0.1,S0,S0-50,S0+50,delta_t,P1)*np.exp(-u0)
    f_x = (c_p-2*c+c_m)/(0.01)

plt.figure(figsize=(12,4))
plt.plot(xx,f_x, label = 'implied pdf')
plt.legend()
plt.show()

# %% [markdown]
# There is some oscillation around the second strike which causes the pdf around there to be negative , at some points,
# this imples there is butterfly arbitrage in the in the slice. Theoretically this should not be the case if the algorithm converged, and if the data was arbitrage free. Therefore we conjecture that either there is a problem with our data or some issue with our numerical implementation.  See the report for more discussion
